# %%
# Import necessary functions
from pathlib import Path
import csv


# Identify file path
csvpath = Path('../python-homework-main/pybank.csv')

# Set variables to be held in lists
months = []
pybank = []
change_in_profit = []

# Intitalize line_num variable
line_num = 0

# Open the path as a file
with open(csvpath, 'r') as csvfile:
    
    print(type(csvfile))
    
    csvreader = csv.reader(csvfile, delimiter=',')
    
    print(type(csvreader))
    
#  Identify headers on csv file and switch from 'Date' to 'Profit/Losses' 
    header = next(csvreader)
    line_num += 1

# Print header
    print(f"{header} <---- HEADER")
    
# Read rows after header    
    for row in csvreader:
        
        print(row)
        
        pnl = int(row[1])
        pybank.append(pnl)
        
        
        
# Identify variables to be held 
total_months = 0
total_profits = 0
avg_profits = 0
max_profits = 0
min_profits = 0


# Set conditionals for total months and Profit/Losses over the period
for pnl in pybank:
    total_profits += pnl
    total_months += 1

# To find average montlhy changes in Profit/Loss over the period. We must compare the revenue value to the prior month's value, hense "position - 1".
for position in range(1, len(pybank)):
    change_in_profit.append((int(pybank[position]) - int(pybank[position-1])))
    
avg_profits = round((sum(change_in_profit) / total_months), 2)

# To find greatest increase/decrease in montlhy Profit/Loss
max_profits = max(change_in_profit)

min_profits = min(change_in_profit)

"Confused as how to add months alongside these values. Would have to have python read the csv dile as a Dictionary that way I would be able to correlate Date with Profit/Loss" 

# Create output as text file

output_path = Path('../python-homework-main/output.txt')

# Write Financial Analysis

with open(output_path, 'w') as file:

    file.write(f"Financial Analysis")
    file.write("\n")
    file.write(f'---------------------------------')
    file.write("\n")
    file.write(f"Total Months: {total_months}")
    file.write("\n")
    file.write(f"Total: ${total_profits}")
    file.write("\n")
    file.write(f"Average Change In Profits: ${avg_profits}")
    file.write("\n")
    file.write(f"Greatest Increase in Profits: ${max_profits}")
    file.write("\n")
    file.write(f"Greatest Decrease in Profits: ${min_profits}")
    file.write("\n")
# Out:
# <class '_io.TextIOWrapper'>
# <class '_csv.reader'>
# ['Date', 'Profit/Losses'] <---- HEADER
# ['Jan-2010', '867884']
# ['Feb-2010', '984655']
# ['Mar-2010', '322013']
# ['Apr-2010', '-69417']
# ['May-2010', '310503']
# ['Jun-2010', '522857']
# ['Jul-2010', '1033096']
# ['Aug-2010', '604885']
# ['Sep-2010', '-216386']
# ['Oct-2010', '477532']
# ['Nov-2010', '893810']
# ['Dec-2010', '-80353']
# ['Jan-2011', '779806']
# ['Feb-2011', '-335203']
# ['Mar-2011', '697845']
# ['Apr-2011', '793163']
# ['May-2011', '485070']
# ['Jun-2011', '584122']
# ['Jul-2011', '62729']
# ['Aug-2011', '668179']
# ['Sep-2011', '899906']
# ['Oct-2011', '834719']
# ['Nov-2011', '132003']
# ['Dec-2011', '309978']
# ['Jan-2012', '-755566']
# ['Feb-2012', '1170593']
# ['Mar-2012', '252788']
# ['Apr-2012', '1151518']
# ['May-2012', '817256']
# ['Jun-2012', '570757']
# ['Jul-2012', '506702']
# ['Aug-2012', '-1022534']
# ['Sep-2012', '475062']
# ['Oct-2012', '779976']
# ['Nov-2012', '144175']
# ...
